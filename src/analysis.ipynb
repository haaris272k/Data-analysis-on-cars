# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('US cars.csv')
df
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
# data cleaning
print(df.isnull()) # checking for null values(ex NaN).
df.isnull().sum() # finding sum of null values in a row.
# Out:
#       Unnamed: 0  price  brand  model   year  title_status  mileage  color  \
# 0          False  False  False  False  False         False    False  False
# 1          False  False  False  False  False         False    False  False
# 2          False  False  False  False  False         False    False  False
# 3          False  False  False  False  False         False    False  False
# 4          False  False  False  False  False         False    False  False
# ...          ...    ...    ...    ...    ...           ...      ...    ...
# 2494       False  False  False  False  False         False    False  False
# 2495       False  False  False  False  False         False    False  False
# 2496       False  False  False  False  False         False    False  False
# 2497       False  False  False  False  False         False    False  False
# 2498       False  False  False  False  False         False    False  False
#
#         vin    lot  state  country  condition
# ...

# %%
df.dropna() #removing rows with any null values

# we can remove a number of columns, if they are of no use to us.
del df['Unnamed: 0']
del df['vin']
del df['lot']
del df['condition']
df
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country
# 0     new jersey     usa
# 1      tennessee     usa
# 2        georgia     usa
# ...

# %%
# Starting with some basic analysis.

# analysing the unique brands.
# this function will return a list of unique values from a column.

print("List of all unique brands in the dataset-",df['brand'].unique()) 
print(len(df['brand'].unique()))
# Out:
# List of all unique brands in the dataset- ['toyota' 'ford' 'dodge' 'chevrolet' 'gmc' 'chrysler' 'kia' 'buick'
#  'infiniti' 'mercedes-benz' 'jeep' 'bmw' 'cadillac' 'hyundai' 'mazda'
#  'honda' 'heartland' 'jaguar' 'acura' 'harley-davidson' 'audi' 'lincoln'
#  'lexus' 'nissan' 'land' 'maserati' 'peterbilt' 'ram']
# 28

# %%
# analysing the unique models.

print("List of all unique models in the dataset- ",df['model'].unique()) 
print(len(df['model'].unique()))
# Out:
# List of all unique models in the dataset-  ['cruiser' 'se' 'mpv' 'door' '1500' 'pk' 'malibu' 'coupe' 'wagon' 'forte'
#  'encore' 'sorento' 'doors' 'chassis' 'q70' 'camaro' 'convertible' 'vans'
#  'srw' 'compass' 'enclave' '300' 'cherokee' 'pacifica' 'x3' 'equinox'
#  'challenger' 'm' 'colorado' 'focus' 'durango' 'escape' 'charger'
#  'explorer' 'f-150' '3500' 'caravan' 'van' 'dart' '2500' 'esv' 'cutaway'
#  'el' 'edge' 'series' 'flex' 'srx' 'cab' 'pickup' 'vehicl' 'trax' 'tahoe'
#  'suburban' 'cargo' 'drw' 'fiesta' 'impala' 'soul' 'elantra' 'pioneer'
#  'trail' 'traverse' 'country' 'sundance' 'road/street' 'nautilus' 'gx'
#  'q5' 'gle' 'sportage' '5' 'sport' 'discovery' 'acadia' 'ghibli' 'glc'
#  'e-class' 'truck' 'utility' 'limited' 'sl-class' 'cx-3' '2500hd' 'sonic'
#  'corvette' 'mdx' 'xt5' 'fusion' 'mustang' 'passenger' 'volt' 'spark'
#  'cruze' 'ld' 'journey' 'transit' 'ranger' 'taurus' 'max' 'energi'
#  'expedition' 'bus' 'ecosport' 'f-750' 'd' 'dr' 'hybrid' 'suv' 'connect'
# ...

# %%
# analysing the year.

'''analysing year by putting them in ascending order'''

print("Years in ascending order ",np.sort(df['year'].unique())) 
len(df['year'].unique())
# Out:
# Years in ascending order  [1973 1984 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004
#  2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
#  2019 2020]
# 30

# %%
# analysing type of vehicles.
df['title_status'].unique()
# Out:
# array(['clean vehicle', 'salvage insurance'], dtype=object)

# %%
# analysing the country, like what all countrie's vehicle we are working on.
df['country'].unique()
# Out:
# array([' usa', ' canada'], dtype=object)

# %%
df[df['country']==' canada'] # this way we can access the data pertaining to canada.
# Out:
#      price      brand    model  year   title_status  mileage   color    state  \
# 261  33000  chevrolet     1500  2018  clean vehicle  52521.0   white  ontario
# 813  30000      dodge  charger  2019  clean vehicle  43294.0   white  ontario
# 814  30000      dodge  charger  2019  clean vehicle  54309.0  orange  ontario
# 815  30000      dodge  charger  2019  clean vehicle  52822.0   white  ontario
# 816  30000      dodge  charger  2019  clean vehicle  45554.0   white  ontario
# 817  30000      dodge  charger  2019  clean vehicle  37538.0   white  ontario
# 818  29500      dodge  charger  2019  clean vehicle  35153.0     red  ontario
#
#      country
# 261   canada
# 813   canada
# 814   canada
# 815   canada
# 816   canada
# 817   canada
# 818   canada

# %%
n=df[df['country']==' usa'] # this way we can access data pertaining to usa.
n
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country
# 0     new jersey     usa
# 1      tennessee     usa
# 2        georgia     usa
# ...

# %%
# Q-1 lets find the average price of a car ?
average_price=df['price'].sum()/len(df['price'])
int(average_price)
# Out:
# 18767

# %%
# Q-2 lets find the average mileage of a car ?
average_mileage=df['mileage'].sum()/len(df['mileage'])
int(average_mileage)
# Out:
# 52298

# %%
# Q-3 Find the maximum price of a vehicle
df['price'].max()
# Out:
# 84900

# %%
# Q-4 (b) analyze how many rows are having ford brand ?
df[df['brand']=='ford'] # it will return all the rows having ford brand.
# result shows us that there is data of 1235 cars on ford brand!
# Out:
#       price brand   model  year   title_status   mileage     color  \
# 1      2899  ford      se  2011  clean vehicle  190552.0    silver
# 3     25000  ford    door  2014  clean vehicle   64146.0      blue
# 9      5250  ford     mpv  2017  clean vehicle   63418.0     black
# 14    20700  ford    door  2013  clean vehicle  100757.0     black
# 18     5210  ford     mpv  2017  clean vehicle   35714.0     white
# ...     ...   ...     ...   ...            ...       ...       ...
# 2199  13800  ford  fusion  2019  clean vehicle   29345.0     white
# 2200  56000  ford     srw  2018  clean vehicle   25371.0     black
# 2201  13800  ford  fusion  2019  clean vehicle   30054.0    silver
# 2202  45800  ford     srw  2018  clean vehicle   11173.0     white
# 2203  13800  ford  fusion  2019  clean vehicle   30902.0  no_color
#
#                state country
# 1          tennessee     usa
# 3           virginia     usa
# 9              texas     usa
# 14          virginia     usa
# ...

# %%
# Q-5 Analyse which brand of car was manufactured the most ?

for i in df['brand'].unique():
   print(i,":",len(df[df['brand']  == i]))

# we took the unique brands then found out no of cars in each brand
# we got to know that ford was the leading brand between 1973 and 2020
# Out:
# toyota : 1
# ford : 1235
# dodge : 432
# chevrolet : 297
# gmc : 42
# chrysler : 18
# kia : 13
# buick : 13
# infiniti : 12
# mercedes-benz : 10
# jeep : 30
# bmw : 17
# cadillac : 10
# hyundai : 15
# mazda : 2
# honda : 12
# heartland : 5
# jaguar : 1
# acura : 3
# harley-davidson : 1
# audi : 4
# lincoln : 2
# lexus : 2
# nissan : 312
# land : 4
# maserati : 1
# peterbilt : 4
# ram : 1

# %%
# Q-6 Analyse which model was manufactured the most ?

for j in df['model'].unique():
    print(j,":",len(df[df['model']==j]))
# we can see that door and f-150 type of mdoel were manufactured the most
# Out:
# cruiser : 1
# se : 1
# mpv : 87
# door : 651
# 1500 : 39
# pk : 5
# malibu : 12
# coupe : 6
# wagon : 30
# forte : 2
# encore : 3
# sorento : 5
# doors : 148
# chassis : 4
# q70 : 1
# camaro : 6
# convertible : 1
# vans : 2
# srw : 38
# compass : 6
# enclave : 2
# 300 : 6
# cherokee : 3
# pacifica : 3
# x3 : 2
# equinox : 18
# challenger : 44
# m : 1
# colorado : 12
# focus : 9
# durango : 64
# escape : 39
# charger : 42
# explorer : 39
# f-150 : 219
# 3500 : 4
# caravan : 102
# van : 46
# dart : 1
# 2500 : 8
# esv : 1
# cutaway : 12
# el : 3
# edge : 34
# series : 8
# flex : 33
# srx : 1
# cab : 8
# pickup : 15
# vehicl : 1
# trax : 8
# tahoe : 9
# suburban : 16
# cargo : 2
# drw : 10
# fiesta : 14
# impala : 12
# soul : 1
# elantra : 1
# pioneer : 1
# trail : 1
# traverse : 6
# country : 2
# sundance : 1
# road/street : 1
# nautilus : 1
# gx : 1
# q5 : 1
# gle : 2
# sportage : 1
# 5 : 1
# sport : 40
# discovery : 1
# acadia : 1
# ghibli : 1
# glc : 1
# e-class : 1
# truck : 4
# ...

# %%
# Q-7  Analyse which type of color of car was manufactured the most ?

for k in df['color'].unique():
    print(k,":",len(df[df['color']==k]))
# Ans- we can see white and black were manu. the most
# Out:
# black : 516
# silver : 300
# blue : 151
# red : 192
# white : 707
# gray : 395
# orange : 20
# brown : 15
# no_color : 61
# gold : 19
# charcoal : 18
# turquoise : 1
# beige : 5
# green : 24
# dark blue : 1
# maroon : 1
# phantom black : 1
# yellow : 9
# color: : 5
# light blue : 1
# toreador red : 1
# bright white clearcoat : 2
# billet silver metallic clearcoat : 3
# black clearcoat : 2
# jazz blue pearlcoat : 1
# purple : 1
# ruby red metallic tinted clearcoat : 2
# triple yellow tri-coat : 3
# competition orange : 1
# off-white : 2
# shadow black : 5
# magnetic metallic : 6
# ingot silver metallic : 4
# ruby red : 1
# royal crimson metallic tinted clearcoat : 1
# kona blue metallic : 1
# oxford white : 4
# lightning blue : 1
# ingot silver : 1
# white platinum tri-coat metallic : 2
# guard : 1
# tuxedo black metallic : 2
# tan : 1
# burgundy : 1
# super black : 3
# cayenne red : 2
# morningsky blue : 1
# pearl white : 1
# glacier white : 1

# %%
# Main questions begins from here!
# Q-8 find the top 5 brands in terms of number of cars ?
# logic = iterating> conv into list> conv into dataframe> sorting will be used> visualising

lst=[]

for i in df['brand'].unique():                    # iterating through the values in that coloumn.
    lst.append([i , len(df[df['brand']  == i])])  #converting the data into list.
    
conv_dataframe=pd.DataFrame(lst,columns=['name','freq']) # converting the list to dataframe for ease.

top5_brands=conv_dataframe.sort_values(by='freq',ascending=False).head() 
# sorting and getting top 5 brands and storing that dataframe in a new variable.
top5_brands
# Out:
#          name  freq
# 1        ford  1235
# 2       dodge   432
# 23     nissan   312
# 3   chevrolet   297
# 4         gmc    42

# %%
# visualizing the above data using bar graph.
top5_brands.plot(x='name',y='freq',kind='bar',figsize=(8,8))
plt.show()

# %%
df
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country
# 0     new jersey     usa
# 1      tennessee     usa
# 2        georgia     usa
# ...

# %%
# Q-9 Find the most popular car colors (top 5)
lst2=[]
for n in df['color'].unique():
    lst2.append([n , len(df[df['color']  == n])])
conv_dataframe2=pd.DataFrame(lst2,columns=['color','unit'])
top5_colors=conv_dataframe2.sort_values(by='unit',ascending=False).head()
top5_colors
# Out:
#     color  unit
# 4   white   707
# 0   black   516
# 5    gray   395
# 1  silver   300
# 3     red   192

# %%
# visualizing the above data using bar graph
top5_colors.plot(x='color',y='unit',kind='bar',figsize=(8,8))
plt.show()

# %%
# Q-10 Which car brand is having maximum average price.
# groupby() function will come into use.
# It is used for grouping the data according to the categories and apply a function to the categories. 
# It also helps to aggregate data efficiently.

for_mxavg=df.groupby('brand').mean()['price'].sort_values(ascending=False).plot(kind='bar',figsize=(16,6)) #find the max avg price of each brand and sort.
plt.show()

# %%
# Q-11 Which state is having average of most expensive cars.
df.groupby('state').mean()['price'].sort_values(ascending=False).plot(kind='bar',figsize=(20,6))
plt.show()

# Now we could easily make out the states where the cars should be manufactured to have a maximum profit
